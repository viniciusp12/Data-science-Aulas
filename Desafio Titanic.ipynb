# %%
import pandas as pd

titanic = pd.read_csv("predict.csv")
titanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %%
titanic.columns = ["passageirosId", "sobreviventesId"]
titanic.head()
# Out:
#    passageirosId  sobreviventesId
# 0            892                0
# 1            893                0
# 2            894                0
# 3            895                0
# 4            896                0

# %%
titanic['sobreviventesId']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    1
# Name: sobreviventesId, Length: 418, dtype: int64

# %%
titanic['sobreviventesId'].unique() #1 ou 0, vivo ou morto
# Out:
# array([0, 1])

# %%
titanic['sobreviventesId'].value_counts()
# Out:
# 0    316
# 1    102
# Name: sobreviventesId, dtype: int64

# %%
titanic.sobreviventesId.describe()
# Out:
# count    418.000000
# mean       0.244019
# std        0.430019
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: sobreviventesId, dtype: float64

# %%
titanic.sobreviventesId.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt #outra biblioteca de graficos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-6b3f1c9518b4> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt #outra biblioteca de graficos
#       2
# ----> 3 sns.catplot(x = "original_language", kind = "count", data = titanic)
#
# NameError: name 'sns' is not defined
